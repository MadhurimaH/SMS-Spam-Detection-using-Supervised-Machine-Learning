# %%
#This code generates a bar graph that compares the accuracy, precision and recall values of the algorithms we implemented.

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

n_groups=6
index = np.arange(n_groups)
bar_width = 0.2
opacity = 0.8

a=[0.9647129186602871,0.9395933014354066,0.9539473684210527,0.9366028708133971,0.9694976076555024,0.9455741626794258]
y=["Adaboost","Decision Tree","Logistic Reg","Naive Bayes","Random Forest","Svm"]
y_pos=np.arange(len(y))

p=[0.9425285650690013,0.8740774049967227,0.9341577540106951,0.8563103563103562,0.9543660265119525,0.9454074579435896]
r=[0.9046282337333413,0.8699662304769945,0.8564775112186633,0.910963687150838,0.9218623481781376,0.8094604750663452]
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
rects1 = plt.bar(index, p, bar_width,
                 alpha=opacity,
                 color='r',
                 label='precision')
 
rects2 = plt.bar(index + bar_width, r, bar_width,
                 alpha=opacity,
                 color='b',
                 label='recall')
rects3=plt.bar(index+bar_width+bar_width,a,bar_width,alpha=opacity,color='y',label='accuracy')


plt.xticks(y_pos+0.2, y,rotation='vertical')
#plt.fit()
plt.ylabel('Precision,Recall,Accuracy at 70:30 training-test split')
plt.xlabel('Algorithms')

plt.title("Comparison of precision,recall and accuracy of the implemented algorithms")
#plt.xlabel('configurations')
#plt.ylabel('percentage to represent precision and recall')
#plt.title('Precision and Recall Values')
#plt.xticks(index+0.15, ('50:50', '60:40', '70:30', '80:20', '90:10'))
plt.legend()
plt.yticks(np.arange(0, 1, step=0.1))
plt.tight_layout()
plt.show()

# %%
#This code generates a bar graph that compares the precision and recall values of the algorithms we implemented.

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure

n_groups=6
index = np.arange(n_groups)
bar_width = 0.25
opacity = 0.8

a=[0.9647129186602871,0.9395933014354066,0.9539473684210527,0.9366028708133971,0.9694976076555024,0.9455741626794258]
y=["Adaboost","Decision Tree","Logistic Reg","Naive Bayes","Random Forest","Svm"]
y_pos=np.arange(len(y))

p=[0.9425285650690013,0.8740774049967227,0.9341577540106951,0.8563103563103562,0.9543660265119525,0.9454074579435896]
r=[0.9046282337333413,0.8699662304769945,0.8564775112186633,0.910963687150838,0.9218623481781376,0.8094604750663452]
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
rects1 = plt.bar(index, p, bar_width,
                 alpha=opacity,
                 color='r',
                 label='precision')
 
rects2 = plt.bar(index + bar_width, r, bar_width,
                 alpha=opacity,
                 color='b',
                 label='recall')
#rects3=plt.bar(index+bar_width+bar_width,a,bar_width,alpha=opacity,color='y',label='accuracy')


plt.xticks(y_pos, y,rotation='vertical')
#plt.fit()
plt.ylabel('Precision,Recall,Accuracy at 70:30 training-test split')
plt.xlabel('Algorithms')

plt.title("Comparison of precision,recall and accuracy of the implemented algorithms")
#plt.xlabel('configurations')
#plt.ylabel('percentage to represent precision and recall')
#plt.title('Precision and Recall Values')
#plt.xticks(index+0.15, ('50:50', '60:40', '70:30', '80:20', '90:10'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
#This code generates a bar graph that compares accuracy values of the algorithms we implemented.

import matplotlib.pyplot as plt
import numpy as np

a=[0.9647129186602871,0.9395933014354066,0.9539473684210527,0.9366028708133971,0.9694976076555024,0.9455741626794258]
y=["Adaboost","Decision Tree","Logistic Reg","Naive Bayes","Random Forest","Svm"]
y_pos=np.arange(len(y))


fig, ax = plt.subplots()
b=plt.bar(y_pos, a,  align='center',alpha=0.7)
#bar_width = 0.35
plt.xticks(y_pos, y,rotation='vertical')
#plt.fit()
plt.ylabel('Accuracy at 70:30 training-test split')
plt.xlabel('Algorithms')

plt.title("Comparison of accuracy of the implemented algorithms")
plt.tight_layout()
